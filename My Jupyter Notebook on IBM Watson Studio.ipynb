# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Mindaugas Griguola__ Occupation: Production Planner

# %% [markdown]
# I am interested in data science because it can help understand how things work and how to discover innficiencies. It can also provide facts and interesting points of view that could not be discovered without the use of data.

# %% [markdown]
# Objectives:
#
# 1. Learned a number of data science languages
# 2. Learend a number of data science tools
# 3. Learned how to use simple functions and commenting

# %% [markdown]
# ### The below code shows an arithmetic example

# %%
45+5*12
# Out:
# 105

# %% [markdown]
# https://keyassets.timeincuk.net/inspirewp/live/wp-content/uploads/sites/8/2017/09/C60X5B-scaled-e1580221040192.jpg

# %% [markdown]
# Data Science Libraries:
# 1. TensorFlow
# 2. NumPy
# 3. SciPy
# 4. Pandas
# 5. Matplotlib

# %% [markdown]
# Data Science Languages:
#  - Python
#  - R
#  - SQL

# %% [markdown]
# Data Science Tools:
#
# 1. MATLAB
# 2. IBM Watson Studio
# 3. Tableau
# 4. Jupyter
# 5. Apache Spark

# %%
minutes = 260

hours = minutes / 60

print (hours)
# Out:
# 4.333333333333333
